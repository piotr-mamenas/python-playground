# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import normalize

# %matplotlib inline

# %%
x = np.linspace(0,20,50)
y = x**2

# %%
plt.plot(x,y,'r--')
plt.xlim(0,15)
plt.ylim(0,250)
plt.title("PLOT")
plt.xlabel("X label")
plt.ylabel("Y label")
# Out:
# Text(0,0.5,'Y label')

# %%
var = np.linspace(0,100,144).reshape(12,12)

# %%
plt.plot(var)

# %%
df = pd.read_csv('housing.csv')

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
plt.scatter(df['median_income'],df['median_house_value'])

# %%
normalized = normalize(df[['median_house_value','population']].as_matrix())

x = normalized[:,0]
y = normalized[:,1]
plt.scatter(x,y,zorder=1)
plt.plot(x,y,zorder=2,color='red')
plt.xlabel("median_house_value")
plt.ylabel("population")

print(normalized[0,1])
# Out:
# 0.0007114448044835228

# %%
df.iloc[:,0:8]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
df['median_house_value']
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
# 5        269700.0
# 6        299200.0
# 7        241400.0
# 8        226700.0
# 9        261100.0
# 10       281500.0
# 11       241800.0
# 12       213500.0
# 13       191300.0
# 14       159200.0
# 15       140000.0
# 16       152500.0
# 17       155500.0
# 18       158700.0
# 19       162900.0
# 20       147500.0
# 21       159800.0
# 22       113900.0
# 23        99700.0
# 24       132600.0
# 25       107500.0
# 26        93800.0
# 27       105500.0
# 28       108900.0
# 29       132000.0
#            ...
# 20610     45500.0
# 20611     47000.0
# 20612     48300.0
# 20613     53400.0
# 20614     58000.0
# 20615     57500.0
# 20616     55100.0
# 20617     70800.0
# 20618     63400.0
# 20619     99100.0
# 20620    100000.0
# 20621     77500.0
# 20622     67000.0
# 20623     65500.0
# 20624     87200.0
# 20625     72000.0
# 20626     93800.0
# 20627    162500.0
# 20628     92400.0
# ...

# %%
x = df.iloc[:,0:8]
y = df['median_house_value']

scaler = MinMaxScaler()
#x = scaler.fit_transform(x)
#y = scaler.fit_transform(y)

is_nan = np.any(np.isnan(x))
is_finite = np.all(np.isfinite(x))

print(is_nan)
print(is_finite)

z = df[df['longitude'] == np.nan]
print(z)
# Out:
# True
# False
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
x.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# dtype: int64

# %%
nullx = x[x['total_bedrooms'].isnull()]
stdx = np.std(nullx.iloc[:,0:9])
print(stdx)

nulldf = df[df['total_bedrooms'].isnull()]
stdx = np.std(df.iloc[:,0:9])
print(stdx)

print(df['total_bedrooms'].mean())
# Out:
# longitude                1.996584
# latitude                 2.092226
# housing_median_age      11.935991
# total_rooms           1782.947486
# total_bedrooms                NaN
# population            1054.890897
# households             385.186917
# median_income            1.950865
# dtype: float64
# longitude                  2.003483
# latitude                   2.135901
# housing_median_age        12.585253
# total_rooms             2181.562402
# total_bedrooms           421.374759
# population              1132.434688
# households               382.320491
# median_income              1.899776
# median_house_value    115392.820404
# dtype: float64
# 537.8705525375618

# %%
df[df['total_bedrooms'].isnull()].iloc[:,4:5].replace(np.nan,df['total_bedrooms'].mean())
# Out:
#        total_bedrooms
# 290        537.870553
# 341        537.870553
# 538        537.870553
# 563        537.870553
# 696        537.870553
# 738        537.870553
# 1097       537.870553
# 1350       537.870553
# 1456       537.870553
# 1493       537.870553
# 1606       537.870553
# 2028       537.870553
# 2115       537.870553
# 2301       537.870553
# 2323       537.870553
# 2334       537.870553
# 2351       537.870553
# 2412       537.870553
# 2420       537.870553
# 2578       537.870553
# 2608       537.870553
# 2647       537.870553
# 2826       537.870553
# 3024       537.870553
# 3328       537.870553
# 3354       537.870553
# 3376       537.870553
# 3482       537.870553
# 3485       537.870553
# 3529       537.870553
# ...               ...
# 18466      537.870553
# 18786      537.870553
# 18873      537.870553
# 18914      537.870553
# 19060      537.870553
# 19071      537.870553
# 19122      537.870553
# 19150      537.870553
# 19252      537.870553
# ...

# %%
x = df.iloc[:,0:8]
y = df['median_house_value']

scaler = MinMaxScaler()
#x = scaler.fit_transform(x)
#y = scaler.fit_transform(y)

is_nan = np.any(np.isnan(x))
is_finite = np.all(np.isfinite(x))

print(is_nan)
print(is_finite)

z = df[df['longitude'] == np.nan]
print(z)
# Out:
# True
# False
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
mean = df['total_bedrooms'].mean()
df.loc[df.total_bedrooms==np.nan,'total_bedrooms'] = mean
